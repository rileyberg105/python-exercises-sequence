# %% [markdown]
# # Debug Maths Operators
#
# In this notebook you will find and fix bugs in programs that use maths operators.
#
# > 💡 **Stuck?** Use the [Arithmetic Cheatsheet](../../additional-resources/ARITHMETIC_CHEATSHEET.md) to remind yourself what each operator does.
#
# ## What you will practise
# - Floor division `//` to get whole groups.
# - Modulus `%` to find the remainder.
# - `round(value, places)` to control decimal places.
# - Using variables, `input()`, casting with `int()` and `float()`, and f-strings.
#
# ## How to work
# 1. Read the task and **expected output** carefully.
# 2. Run the buggy code — observe the error or wrong output.
# 3. Fix the bug(s) so the output matches exactly.
# 4. Write a short explanation of what was wrong.
# 5. Run `uv run pytest -q` to check your work.

# %% [markdown]
# ## Exercise 1 — Full groups only
#
# **Expected output:**
# ```
# Full groups: 6
# ```
#
# **Task:** Fix the operator bug AND convert the `print` line to use an f-string instead of `+` concatenation.

# %%
students = 25
group_size = 4
full_groups = students // group_size
print("Full groups: " + str(full_groups))
# Out:
# Full groups: 6

# %% [markdown]
# ### What actually happened
# Describe what error or wrong output you got, and what you changed to fix it.

# %% [markdown]
# ## Exercise 2 — Find the leftover
#
# **Expected output:**
# ```
# Leftover: 1
# ```
#
# **Task:** Fix the operator bug AND convert the `print` line to use an f-string instead of `+` concatenation.

# %%
sweets = 25
per_bag = 4
leftover = sweets % per_bag
print("Leftover: " + str(leftover))
# Out:
# Leftover: 1

# %% [markdown]
# ### What actually happened
# Describe what error or wrong output you got, and what you changed to fix it.

# %% [markdown]
# ## Exercise 3 — Round an average
#
# **Expected output:**
# ```
# Average: 6.7
# ```

# %%
total = 20
count = 3
average = total / count
average = round(average, 1)
print(f"Average: {average}")
# Out:
# Average: 6.7

# %% [markdown]
# ### What actually happened
# Describe what error or wrong output you got, and what you changed to fix it.

# %% [markdown]
# ## Exercise 4 — Teams from input
#
# **Expected output:**
# ```
# How many players? [⌨️: 23]
# Full teams: 4
# ```

# %%
players = input(" How many players? ")
teams = players / 5
print(f"Full teams: {teams}")
# Out:
# Full teams:

# %% [markdown]
# ### What actually happened
# Describe what error or wrong output you got, and what you changed to fix it.

# %% [markdown]
# ## Exercise 5 — Round money to 2 decimal places
#
# **Expected output:**
# ```
# Total: £3.77
# ```

# %%
price = 1.257
qty = 3
total = price * qty
total = round(total, 2)
print(f"Total: £{price}")

# %% [markdown]
# ### What actually happened
# Describe what error or wrong output you got, and what you changed to fix it.

# %% [markdown]
# ## Exercise 6 — Split minutes
#
# **Expected output:**
# ```
# 200 minutes is 3 hours and 20 minutes
# ```

# %%
minutes = 200
hours = minutes / 60
minutes_left = minutes - 60
print(f"{minutes} minutes is {hours} hours and {minutes_left} minutes")

# %% [markdown]
# ### What actually happened
# Describe what error or wrong output you got, and what you changed to fix it.

# %% [markdown]
# ## Exercise 7 — Pence to pounds
#
# **Expected output:**
# ```
# Enter pence: [⌨️: 389]
# 389p is £3 and 89p
# ```

# %%
pence = input("Enter pence: ")
pounds = pence // 100
leftover = pence - 100
print(f"{pence}p is £{pounds} and {leftover}p")

# %% [markdown]
# ### What actually happened
# Describe what error or wrong output you got, and what you changed to fix it.

# %% [markdown]
# ## Exercise 8 — Area of a square
#
# **Expected output:**
# ```
# Area of square: 5.5
# ```

# %%
length = 2.345
area = length * length
rounded = round(area, 3)
print(f"Area of square: {area}")

# %% [markdown]
# ### What actually happened
# Describe what error or wrong output you got, and what you changed to fix it.

# %% [markdown]
# ## Exercise 9 — Apples into bags
#
# **Expected output:**
# ```
# Full bags: 9, Left over: 2
# ```

# %%
apples = 47
per_bag = 5
bags = apples / per_bag
left = apples % per_bag
print("Full bags: {bags}, Left over: {left}")

# %% [markdown]
# ### What actually happened
# Describe what error or wrong output you got, and what you changed to fix it.

# %% [markdown]
# ## Exercise 10 — Mixed challenge
#
# **Expected output:**
# ```
# How many items? [⌨️: 29]
# How many per box? [⌨️: 6]
# Total cost? £ [⌨️: 10.99]
# Full boxes: 4
# Leftover items: 5
# Cost per box: £2.75
# ```

# %%
items = input("How many items? ")
box_size = input("How many per box? ")
total_cost = float(input("Total cost? £"))

boxes = items / box_size
leftover = items - box_size
cost_per_box = total_cost / boxes
cost_per_box = round(cost_per_box, 2)

print(f"Full boxes: {boxes}")
print(f"Leftover items: {leftover}")
print(f"Cost per box: £{cost_per_box}")

# %% [markdown]
# ### What actually happened
# Describe what errors or wrong output you got, and what you changed to fix them.

# %%
# Self-check scratch cell (not graded)
# You can run small experiments here.

# %%
from exercise_runtime_support.student_checker import run_notebook_checks

# Pass the canonical exercise_key here; do not pass a notebook path.
run_notebook_checks('ex013_sequence_debug_maths_operators')
# Out:
# +-------------+---------------------------------+----------+------------------------------------------+
# | Exercise    | Check                           | Status   | Error                                    |
# +=============+=================================+==========+==========================================+
# | Exercise 1  | Full groups only                | 🔴 NO    | Expected: 'Full groups: 6'      Got:     |
# |             |                                 |          | 'Full groups: 6.25'                      |
# +-------------+---------------------------------+----------+------------------------------------------+
# |             | Explain what went wrong         | 🔴 NO    | explanation needs more detail.           |
# +-------------+---------------------------------+----------+------------------------------------------+
# | Exercise 2  | Find the leftover               | 🔴 NO    | Expected: 'Leftover: 1'      Got:        |
# |             |                                 |          | 'Leftover: 21'                           |
# +-------------+---------------------------------+----------+------------------------------------------+
# |             | Explain what went wrong         | 🔴 NO    | explanation needs more detail.           |
# +-------------+---------------------------------+----------+------------------------------------------+
# | Exercise 3  | Round an average                | 🔴 NO    | Expected: 'Average: 6.7'      Got:       |
# |             |                                 |          | 'Average: 6.666666666666667'             |
# +-------------+---------------------------------+----------+------------------------------------------+
# |             | Explain what went wrong         | 🔴 NO    | explanation needs more detail.           |
# +-------------+---------------------------------+----------+------------------------------------------+
# | Exercise 4  | Teams from input                | 🔴 NO    | Execution failed for code tagged         |
# |             |                                 |          | 'exercise4' in /workspaces/PythonExercis |
# |             |                                 |          | eGeneratorAndDistributor/exercises/seque |
# |             |                                 |          | nce/ex013_sequence_debug_maths_operators |
# |             |                                 |          | /notebooks/student.ipynb: unsupported    |
# |             |                                 |          | operand type(s) for //: 'str' and 'int'  |
# +-------------+---------------------------------+----------+------------------------------------------+
# |             | Explain what went wrong         | 🔴 NO    | explanation needs more detail.           |
# +-------------+---------------------------------+----------+------------------------------------------+
# | Exercise 5  | Round money to 2 decimal places | 🔴 NO    | Expected: 'Total: £3.77'      Got:       |
# |             |                                 |          | 'Total: £1.257'                          |
# +-------------+---------------------------------+----------+------------------------------------------+
# |             | Explain what went wrong         | 🔴 NO    | explanation needs more detail.           |
# +-------------+---------------------------------+----------+------------------------------------------+
# | Exercise 6  | Split minutes                   | 🔴 NO    | Expected: '200 minutes is 3 hours and 20 |
# |             |                                 |          | minutes'      Got: '200 minutes is       |
# |             |                                 |          | 3.3333333333333335 hours and 140         |
# |             |                                 |          | minutes'                                 |
# +-------------+---------------------------------+----------+------------------------------------------+
# |             | Explain what went wrong         | 🔴 NO    | explanation needs more detail.           |
# +-------------+---------------------------------+----------+------------------------------------------+
# | Exercise 7  | Pence to pounds                 | 🔴 NO    | Execution failed for code tagged         |
# |             |                                 |          | 'exercise7' in /workspaces/PythonExercis |
# |             |                                 |          | eGeneratorAndDistributor/exercises/seque |
# |             |                                 |          | nce/ex013_sequence_debug_maths_operators |
# |             |                                 |          | /notebooks/student.ipynb: unsupported    |
# |             |                                 |          | operand type(s) for //: 'str' and 'int'  |
# +-------------+---------------------------------+----------+------------------------------------------+
# |             | Explain what went wrong         | 🔴 NO    | explanation needs more detail.           |
# +-------------+---------------------------------+----------+------------------------------------------+
# | Exercise 8  | Area of a square                | 🔴 NO    | Expected: 'Area of square: 5.5'          |
# |             |                                 |          | Got: 'Area of square:                    |
# |             |                                 |          | 5.4990250000000005'                      |
# +-------------+---------------------------------+----------+------------------------------------------+
# |             | Explain what went wrong         | 🔴 NO    | explanation needs more detail.           |
# +-------------+---------------------------------+----------+------------------------------------------+
# | Exercise 9  | Apples into bags                | 🔴 NO    | Expected: 'Full bags: 9, Left over: 2'   |
# |             |                                 |          | Got: 'Full bags: {bags}, Left over:      |
# |             |                                 |          | {left}'                                  |
# +-------------+---------------------------------+----------+------------------------------------------+
# |             | Explain what went wrong         | 🔴 NO    | explanation needs more detail.           |
# +-------------+---------------------------------+----------+------------------------------------------+
# | Exercise 10 | Mixed challenge                 | 🔴 NO    | Execution failed for code tagged         |
# |             |                                 |          | 'exercise10' in /workspaces/PythonExerci |
# |             |                                 |          | seGeneratorAndDistributor/exercises/sequ |
# |             |                                 |          | ence/ex013_sequence_debug_maths_operator |
# |             |                                 |          | s/notebooks/student.ipynb: unsupported   |
# |             |                                 |          | operand type(s) for /: 'str' and 'str'   |
# +-------------+---------------------------------+----------+------------------------------------------+
# |             | Explain what went wrong         | 🔴 NO    | explanation needs more detail.           |
# +-------------+---------------------------------+----------+------------------------------------------+
